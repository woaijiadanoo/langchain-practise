# %%
! pip install langchain_anthropic
! pip install langchain_core
# Out:
# Collecting langchain_anthropic
#   Using cached langchain_anthropic-0.3.22-py3-none-any.whl.metadata (1.9 kB)
# Collecting anthropic<1.0.0,>=0.69.0 (from langchain_anthropic)
#   Using cached anthropic-0.69.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.78 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain_anthropic) (0.3.79)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain_anthropic) (2.11.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from anthropic<1.0.0,>=0.69.0->langchain_anthropic) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from anthropic<1.0.0,>=0.69.0->langchain_anthropic) (1.9.0)
# Collecting docstring-parser<1,>=0.15 (from anthropic<1.0.0,>=0.69.0->langchain_anthropic)
#   Using cached docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from anthropic<1.0.0,>=0.69.0->langchain_anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from anthropic<1.0.0,>=0.69.0->langchain_anthropic) (0.11.0)
# Requirement already satisfied: sniffio in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from anthropic<1.0.0,>=0.69.0->langchain_anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\ts\appdata\roaming\python\python311\site-packages (from anthropic<1.0.0,>=0.69.0->langchain_anthropic) (4.14.1)
# Requirement already satisfied: idna>=2.8 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from anyio<5,>=3.5.0->anthropic<1.0.0,>=0.69.0->langchain_anthropic) (3.10)
# Requirement already satisfied: certifi in c:\users\ts\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.69.0->langchain_anthropic) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.69.0->langchain_anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic<1.0.0,>=0.69.0->langchain_anthropic) (0.16.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (0.4.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (6.0.3)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_anthropic) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_anthropic) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.78->langchain_anthropic) (2.5.0)
# Using cached langchain_anthropic-0.3.22-py3-none-any.whl (32 kB)
# Using cached anthropic-0.69.0-py3-none-any.whl (337 kB)
# Using cached docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Installing collected packages: docstring-parser, anthropic, langchain_anthropic
#
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ------------- -------------------------- 1/3 [anthropic]
#    ---------------------------------------- 3/3 [langchain_anthropic]
#
# Successfully installed anthropic-0.69.0 docstring-parser-0.17.0 langchain_anthropic-0.3.22
# Requirement already satisfied: langchain_core in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (0.3.79)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain_core) (0.4.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain_core) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain_core) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain_core) (4.14.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain_core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain_core) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain_core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain_core) (0.25.0)
# Requirement already satisfied: anyio in c:\users\ts\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (4.9.0)
# Requirement already satisfied: certifi in c:\users\ts\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.0.9)
# Requirement already satisfied: idna in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain_core) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain_core) (1.3.1)

# %%
! pip install langchain dotenv
! pip install langchain-deepseek
# Out:
# Collecting langchain
#   Downloading langchain-0.3.27-py3-none-any.whl.metadata (7.8 kB)
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain) (0.3.79)
# Collecting langchain-text-splitters<1.0.0,>=0.3.9 (from langchain)
#   Downloading langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain) (0.4.34)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain) (2.11.7)
# Collecting SQLAlchemy<3,>=1.4 (from langchain)
#   Downloading sqlalchemy-2.0.44-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3,>=2 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith>=0.1.17->langchain) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\ts\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: certifi in c:\users\ts\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Collecting greenlet>=1 (from SQLAlchemy<3,>=1.4->langchain)
#   Using cached greenlet-3.2.4-cp311-cp311-win_amd64.whl.metadata (4.2 kB)
# Collecting python-dotenv (from dotenv)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Downloading langchain-0.3.27-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 5.4 MB/s  0:00:00
# Downloading langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Downloading sqlalchemy-2.0.44-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------- ----- 1.8/2.1 MB 16.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 14.9 MB/s  0:00:00
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Using cached greenlet-3.2.4-cp311-cp311-win_amd64.whl (299 kB)
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Installing collected packages: python-dotenv, greenlet, SQLAlchemy, dotenv, langchain-text-splitters, langchain
#
#    ------ --------------------------------- 1/6 [greenlet]
#    ------------- -------------------------- 2/6 [SQLAlchemy]
#    ------------- -------------------------- 2/6 [SQLAlchemy]
#    ------------- -------------------------- 2/6 [SQLAlchemy]
#    ------------- -------------------------- 2/6 [SQLAlchemy]
#    ------------- -------------------------- 2/6 [SQLAlchemy]
#    ------------- -------------------------- 2/6 [SQLAlchemy]
#    ------------- -------------------------- 2/6 [SQLAlchemy]
#    ------------- -------------------------- 2/6 [SQLAlchemy]
#    ------------- -------------------------- 2/6 [SQLAlchemy]
#    ------------- -------------------------- 2/6 [SQLAlchemy]
#    ------------- -------------------------- 2/6 [SQLAlchemy]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    --------------------------------- ------ 5/6 [langchain]
#    ---------------------------------------- 6/6 [langchain]
#
# Successfully installed SQLAlchemy-2.0.44 dotenv-0.9.9 greenlet-3.2.4 langchain-0.3.27 langchain-text-splitters-0.3.11 python-dotenv-1.1.1
# Requirement already satisfied: langchain-deepseek in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (0.1.4)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.70 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-deepseek) (0.3.79)
# Requirement already satisfied: langchain-openai<1.0.0,>=0.3.28 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-deepseek) (0.3.35)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (0.4.34)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (4.14.1)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (2.11.7)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (3.0.0)
# Requirement already satisfied: openai<3.0.0,>=1.104.2 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-openai<1.0.0,>=0.3.28->langchain-deepseek) (2.3.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-openai<1.0.0,>=0.3.28->langchain-deepseek) (0.12.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (0.25.0)
# Requirement already satisfied: anyio in c:\users\ts\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (4.9.0)
# Requirement already satisfied: certifi in c:\users\ts\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (1.0.9)
# Requirement already satisfied: idna in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai<1.0.0,>=0.3.28->langchain-deepseek) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai<1.0.0,>=0.3.28->langchain-deepseek) (0.11.0)
# Requirement already satisfied: sniffio in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai<1.0.0,>=0.3.28->langchain-deepseek) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from openai<3.0.0,>=1.104.2->langchain-openai<1.0.0,>=0.3.28->langchain-deepseek) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (0.4.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai<1.0.0,>=0.3.28->langchain-deepseek) (2025.9.18)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-deepseek) (2.5.0)
# Requirement already satisfied: colorama in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from tqdm>4->openai<3.0.0,>=1.104.2->langchain-openai<1.0.0,>=0.3.28->langchain-deepseek) (0.4.6)

# %%
! pip install --upgrade jupyter ipywidgets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter in c:\users\jz292\appdata\roaming\python\python313\site-packages (1.1.1)
# Requirement already satisfied: ipywidgets in c:\users\jz292\appdata\roaming\python\python313\site-packages (8.1.7)
# Requirement already satisfied: notebook in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter) (7.4.7)
# Requirement already satisfied: jupyter-console in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter) (6.30.1)
# Requirement already satisfied: jupyterlab in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter) (4.4.9)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipywidgets) (9.6.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: colorama in c:\softwares\python\miniconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\softwares\python\miniconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\jz292\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (1.8.17)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (5.8.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\softwares\python\miniconda3\lib\site-packages (from ipykernel->jupyter) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from ipykernel->jupyter) (6.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\softwares\python\miniconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.7)
# Requirement already satisfied: pywin32>=300 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (311)
# Requirement already satisfied: six>=1.5 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\softwares\python\miniconda3\lib\site-packages (from jupyterlab->jupyter) (78.1.1)
# Requirement already satisfied: anyio in c:\users\jz292\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.11.0)
# Requirement already satisfied: certifi in c:\softwares\python\miniconda3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\jz292\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\softwares\python\miniconda3\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.7)
# Requirement already satisfied: h11>=0.16 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.9.0)
# Requirement already satisfied: babel>=2.10 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: requests>=2.31 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\jz292\appdata\roaming\python\python313\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\softwares\python\miniconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\jz292\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\jz292\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\jz292\appdata\roaming\python\python313\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\softwares\python\miniconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\softwares\python\miniconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\softwares\python\miniconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in c:\softwares\python\miniconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21)
# Requirement already satisfied: soupsieve>1.2 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\softwares\python\miniconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (4.12.2)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20251008)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jz292\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\jz292\appdata\roaming\python\python313\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)

# %%
! pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.4-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-core<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_core-1.0.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Downloading langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain_community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain_community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.13.1-cp311-cp311-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain_community) (9.1.2)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain_community) (0.4.34)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain_community) (0.4.1)
# Collecting numpy>=1.26.2 (from langchain_community)
#   Downloading numpy-2.3.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading frozenlist-1.8.0-cp311-cp311-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading multidict-6.7.0-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading propcache-0.4.1-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading yarl-1.22.0-cp311-cp311-win_amd64.whl.metadata (77 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.0.0 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Downloading langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain-core<2.0.0,>=1.0.0->langchain_community) (4.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.0->langchain_community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\ts\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.9.0)
# Requirement already satisfied: certifi in c:\users\ts\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: idna in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain_community) (3.2.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.3.1)
# Downloading langchain_community-0.4-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.5 MB ? eta -:--:--
#    ---------------------------- ----------- 1.8/2.5 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 6.3 MB/s  0:00:00
# Downloading aiohttp-3.13.1-cp311-cp311-win_amd64.whl (454 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 8.3 MB/s  0:00:00
# Downloading langchain_core-1.0.0-py3-none-any.whl (467 kB)
# Downloading langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.0-cp311-cp311-win_amd64.whl (46 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.22.0-cp311-cp311-win_amd64.whl (86 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-win_amd64.whl (44 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading numpy-2.3.4-cp311-cp311-win_amd64.whl (13.1 MB)
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/13.1 MB 5.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.9/13.1 MB 6.7 MB/s eta 0:00:02
#    ------------ --------------------------- 4.2/13.1 MB 6.6 MB/s eta 0:00:02
#    ------------------- -------------------- 6.3/13.1 MB 7.3 MB/s eta 0:00:01
#    ------------------------ --------------- 8.1/13.1 MB 7.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.7/13.1 MB 7.6 MB/s eta 0:00:01
#    ------------------------------------ --- 12.1/13.1 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 13.1/13.1 MB 8.0 MB/s  0:00:01
# Downloading propcache-0.4.1-cp311-cp311-win_amd64.whl (41 kB)
# Installing collected packages: propcache, numpy, mypy-extensions, multidict, marshmallow, frozenlist, aiohappyeyeballs, yarl, typing-inspect, aiosignal, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain-classic, langchain_community
#
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    -- -------------------------------------  1/16 [numpy]
#    ------- --------------------------------  3/16 [multidict]
#    ----------------- ----------------------  7/16 [yarl]
#    ------------------------- -------------- 10/16 [dataclasses-json]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#   Attempting uninstall: langchain-core
#    --------------------------- ------------ 11/16 [aiohttp]
#     Found existing installation: langchain-core 0.3.79
#    --------------------------- ------------ 11/16 [aiohttp]
#     Uninstalling langchain-core-0.3.79:
#    --------------------------- ------------ 11/16 [aiohttp]
#       Successfully uninstalled langchain-core-0.3.79
#    --------------------------- ------------ 11/16 [aiohttp]
#    ------------------------------ --------- 12/16 [langchain-core]
#    ------------------------------ --------- 12/16 [langchain-core]
#    ------------------------------ --------- 12/16 [langchain-core]
#    ------------------------------ --------- 12/16 [langchain-core]
#    ------------------------------ --------- 12/16 [langchain-core]
#    ------------------------------ --------- 12/16 [langchain-core]
#    ------------------------------ --------- 12/16 [langchain-core]
#   Attempting uninstall: langchain-text-splitters
#    ------------------------------ --------- 12/16 [langchain-core]
#     Found existing installation: langchain-text-splitters 0.3.11
#    ------------------------------ --------- 12/16 [langchain-core]
#     Uninstalling langchain-text-splitters-0.3.11:
#    ------------------------------ --------- 12/16 [langchain-core]
#       Successfully uninstalled langchain-text-splitters-0.3.11
#    ------------------------------ --------- 12/16 [langchain-core]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain-classic]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain_community]
#    ---------------------------------------- 16/16 [langchain_community]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.1 aiosignal-1.4.0 dataclasses-json-0.6.7 frozenlist-1.8.0 langchain-classic-1.0.0 langchain-core-1.0.0 langchain-text-splitters-1.0.0 langchain_community-0.4 marshmallow-3.26.1 multidict-6.7.0 mypy-extensions-1.1.0 numpy-2.3.4 propcache-0.4.1 typing-inspect-0.9.0 yarl-1.22.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.0 which is incompatible.
# langchain 0.3.27 requires langchain-text-splitters<1.0.0,>=0.3.9, but you have langchain-text-splitters 1.0.0 which is incompatible.
# langchain-anthropic 0.3.22 requires langchain-core<1.0.0,>=0.3.78, but you have langchain-core 1.0.0 which is incompatible.
# langchain-deepseek 0.1.4 requires langchain-core<1.0.0,>=0.3.70, but you have langchain-core 1.0.0 which is incompatible.
# langchain-openai 0.3.35 requires langchain-core<1.0.0,>=0.3.78, but you have langchain-core 1.0.0 which is incompatible.

# %%
! pip install pypdf
# Out:
# Collecting pypdf
#   Downloading pypdf-6.1.2-py3-none-any.whl.metadata (7.1 kB)
# Downloading pypdf-6.1.2-py3-none-any.whl (323 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-6.1.2

# %%
! pip install PyMuPDF pillow ipython --upgrade langchain-deepseek langchain-openai langchain-core
# Out:
# Requirement already satisfied: PyMuPDF in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (1.26.5)
# Requirement already satisfied: pillow in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (12.0.0)
# Requirement already satisfied: ipython in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (9.6.0)
# Requirement already satisfied: langchain-deepseek in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (0.1.4)
# Collecting langchain-deepseek
#   Downloading langchain_deepseek-1.0.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: langchain-openai in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (1.0.1)
# Requirement already satisfied: langchain-core in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (1.0.0)
# Requirement already satisfied: colorama in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: decorator in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from ipython) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from ipython) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from ipython) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\ts\appdata\roaming\python\python311\site-packages (from ipython) (4.14.1)
# Requirement already satisfied: wcwidth in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.2.14)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-openai) (2.3.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core) (0.4.34)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langchain-core) (2.11.7)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in c:\users\ts\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (4.9.0)
# Requirement already satisfied: certifi in c:\users\ts\appdata\roaming\python\python311\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core) (0.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.11.0)
# Requirement already satisfied: sniffio in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\ts\appdata\roaming\python\python311\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.9.18)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from jedi>=0.16->ipython) (0.8.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from stack_data->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from stack_data->ipython) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\ts\.conda\envs\langchain-practise\lib\site-packages (from stack_data->ipython) (0.2.3)
# Downloading langchain_deepseek-1.0.0-py3-none-any.whl (7.6 kB)
# Installing collected packages: langchain-deepseek
#   Attempting uninstall: langchain-deepseek
#     Found existing installation: langchain-deepseek 0.1.4
#     Uninstalling langchain-deepseek-0.1.4:
#       Successfully uninstalled langchain-deepseek-0.1.4
# Successfully installed langchain-deepseek-1.0.0
